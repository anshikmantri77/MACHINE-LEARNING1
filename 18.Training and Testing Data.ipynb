# %%
import pandas as pd

df=pd.read_csv("carprice.csv")
df
# Out:
#    mileage  age  sell price
# 0    69000    6       18000
# 1    35000    3       34000
# 2    57000    4       26000
# 3    22500    5       40000
# 4    46000    7       31000
# 5    59000    6       26500
# 6    52000    2       32000
# 7    72000    5       19000
# 8    91000    6       12000
# 9    67000    4       20200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df["mileage"],df['sell price'])

# %%
plt.scatter(df["age"],df["sell price"])

# %%
X=df[['mileage','sell price']]
Y=df[['age','sell price']]

# %%
X
# Out:
#    mileage  sell price
# 0    69000       18000
# 1    35000       34000
# 2    57000       26000
# 3    22500       40000
# 4    46000       31000
# 5    59000       26500
# 6    52000       32000
# 7    72000       19000
# 8    91000       12000
# 9    67000       20200

# %%
Y
# Out:
#    age  sell price
# 0    6       18000
# 1    3       34000
# 2    4       26000
# 3    5       40000
# 4    7       31000
# 5    6       26500
# 6    2       32000
# 7    5       19000
# 8    6       12000
# 9    4       20200

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
#    mileage  sell price
# 2    57000       26000
# 4    46000       31000
# 9    67000       20200
# 8    91000       12000
# 6    52000       32000
# 5    59000       26500
# 7    72000       19000

# %%
len(X_train)
# Out:
# 7

# %%
len(X_test)
# Out:
# 3

# %%
from sklearn.linear_model import LinearRegression  
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([[5.49722685e+00, 3.40000000e+04],
#        [5.19052243e+00, 4.00000000e+04],
#        [6.20775257e+00, 1.80000000e+04]])

# %%
Y_test
# Out:
#    age  sell price
# 1    3       34000
# 3    5       40000
# 0    6       18000

# %%
model.score(X_test,Y_test)
# Out:
# 0.3233283718562565
